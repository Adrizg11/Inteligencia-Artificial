# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrizg11/Inteligencia-Artificial/blob/main/Lecci%C3%B3nPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import pandas as pd and load the dataset
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/Station_Entries_Daily_Totals.csv'
df = pd.read_csv(url)

# %%
# Basic Exploration
print("Shape of the DataFrame:", df.shape)
# Out:
# Shape of the DataFrame: (1158456, 5)

# %%
print("\nHead of the DataFrame:\a", df.head(15))
# Out:
# Head of the DataFrame:             station_id               stationname daytype  rides
# date
# 2017-12-22       41280            Jefferson Park       W   6104
# 2017-12-18       41000          Cermak-Chinatown       W   3636
# 2017-12-02       40280              Central-Lake       A   1270
# 2017-12-19       40140           Dempster-Skokie       W   1759
# 2017-12-03       40690                  Dempster       U    499
# 2017-12-30       41660                Lake/State       A   8615
# 2017-12-17       40180      Oak Park-Forest Park       U    442
# 2017-12-02       40250  Kedzie-Homan-Forest Park       A   1353
# 2017-12-07       40120               35th/Archer       W   3353
# 2017-12-19       41420        Addison-North Main       W   6034
# 2017-12-16       40270                      Main       A    887
# 2017-12-27       41450             Chicago/State       W   9639
# 2017-12-07       41210                Wellington       W   3210
# ...

# %%
print("\nTail of the DataFrame:\a", df.tail(15))
# Out:
# Tail of the DataFrame:             station_id        stationname daytype  rides
# date
# 2023-03-17       41700  Washington/Wabash       W   5589
# 2023-03-18       41700  Washington/Wabash       A   3154
# 2023-03-19       41700  Washington/Wabash       U   2922
# 2023-03-20       41700  Washington/Wabash       W   5932
# 2023-03-21       41700  Washington/Wabash       W   6059
# 2023-03-22       41700  Washington/Wabash       W   5972
# 2023-03-23       41700  Washington/Wabash       W   5856
# 2023-03-24       41700  Washington/Wabash       W   5530
# 2023-03-25       41700  Washington/Wabash       A   3215
# 2023-03-26       41700  Washington/Wabash       U   2965
# 2023-03-27       41700  Washington/Wabash       W   5787
# 2023-03-28       41700  Washington/Wabash       W   6208
# 2023-03-29       41700  Washington/Wabash       W   6188
# 2023-03-30       41700  Washington/Wabash       W   6118
# 2023-03-31       41700  Washington/Wabash       W   5556

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
print(df)
# Out:
#             station_id        stationname daytype  rides
# date
# 2017-12-22       41280     Jefferson Park       W   6104
# 2017-12-18       41000   Cermak-Chinatown       W   3636
# 2017-12-02       40280       Central-Lake       A   1270
# 2017-12-19       40140    Dempster-Skokie       W   1759
# 2017-12-03       40690           Dempster       U    499
# ...                ...                ...     ...    ...
# 2023-03-27       41700  Washington/Wabash       W   5787
# 2023-03-28       41700  Washington/Wabash       W   6208
# 2023-03-29       41700  Washington/Wabash       W   6188
# 2023-03-30       41700  Washington/Wabash       W   6118
# 2023-03-31       41700  Washington/Wabash       W   5556
#
# [1158456 rows x 4 columns]

# %%
# Basic Statistics
basic_stats = df.describe()
print("\aBasic Statistics:\a", basic_stats)
# Out:
# Basic Statistics:          station_id         rides
# count  1.158456e+06  1.158456e+06
# mean   4.076671e+04  3.041143e+03
# std    4.491984e+02  3.108889e+03
# min    4.001000e+04  0.000000e+00
# 25%    4.037000e+04  9.570000e+02
# 50%    4.076000e+04  1.990000e+03
# 75%    4.115000e+04  4.004000e+03
# max    4.170000e+04  3.632300e+04

# %%
# Selection Based on Conditionals
min_entries_station = df.loc[df['rides'].idxmin()]
print("\aStation with the Fewest Entries:\a", min_entries_station)
# Out:
# Station with the Fewest Entries:             station_id          stationname daytype  rides
# date
# 2017-12-25       40200      Randolph/Wabash       U      0
# 2017-12-25       40310       Western-Orange       U    541
# 2017-12-25       41150        Kedzie-Midway       U    484
# 2017-12-25       40610            Ridgeland       U    134
# 2017-12-25       40920  Pulaski-Forest Park       U    692
# ...                ...                  ...     ...    ...
# 2017-12-25       41230        47th-Dan Ryan       U    862
# 2017-12-25       40630       Clark/Division       U   1292
# 2017-12-25       41040        Kedzie-Cermak       U    233
# 2017-12-25       40150       Pulaski-Cermak       U    324
# 2017-12-25       40290         Ashland/63rd       U    393
#
# [145 rows x 4 columns]

# %%
max_entries_station = df.loc[df['rides'].idxmax()]
print("\aStation with the Most Entries:\a", max_entries_station)
# Out:
# Station with the Most Entries:             station_id          stationname daytype  rides
# date
# 2015-06-28       40280         Central-Lake       U   1567
# 2015-06-28       41310              Paulina       U   1440
# 2015-06-28       40080             Sheridan       U  10587
# 2015-06-28       40430  Clinton-Forest Park       U   1759
# 2015-06-28       41330      Montrose-O'Hare       U   1221
# ...                ...                  ...     ...    ...
# 2015-06-28       41480        Western-Brown       U   2734
# 2015-06-28       40870            Francisco       U    839
# 2015-06-28       40030         Pulaski-Lake       U   1138
# 2015-06-28       40120          35th/Archer       U   2231
# 2015-06-28       41510          Morgan-Lake       U   1277
#
# [144 rows x 4 columns]

# %%
# Sort the DataFrame by Date
df.sort_values(by='date', inplace=True)

# %%
# Sanity Checking
Morgan_Lake = df[df['stationname'] == 'Morgan-Lake']
Addison_Brown = df[df['stationname'] == 'Addison-Brown']

# %%
# Visualizing Timeseries Data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize': (11, 4)})

# %%
# Plot for Morgan_Lake
Morgan_Lake['rides'].plot(linewidth=0.5)
plt.title('Morgan-Lake Entries Over Time')
plt.xlabel('Date')
plt.ylabel('Entries')
plt.show()

# %%
# Plot for Addison_Brown
Addison_Brown['rides'].plot(linewidth=0.5)
plt.title('Addison-Brown Entries Over Time')
plt.xlabel('Date')
plt.ylabel('Entries')
plt.show()
